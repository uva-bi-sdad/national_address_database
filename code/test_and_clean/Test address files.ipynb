# %%
import geopandas as gpd
import pandas as pd
from pathlib import Path
from tqdm import tqdm
import requests
from bs4 import BeautifulSoup
import io

# %% [markdown]
# # For each address.csv.xz, check that the set of geoids match the set of geoids from the shapefiles. If not, fix those rows

# %%
address_dir = '../../data/address/'
shapefile_dir = '../../data/shapefiles'

# %%
p = Path(address_dir).iterdir()
xz_files = sorted([x for x in p if x.is_file() and x.suffix=='.xz'])
xz_files
# Out:
# [PosixPath('../../data/address/01001.csv.xz'),
#  PosixPath('../../data/address/01003.csv.xz'),
#  PosixPath('../../data/address/01005.csv.xz'),
#  PosixPath('../../data/address/01007.csv.xz'),
#  PosixPath('../../data/address/01009.csv.xz'),
#  PosixPath('../../data/address/01011.csv.xz'),
#  PosixPath('../../data/address/01013.csv.xz'),
#  PosixPath('../../data/address/01015.csv.xz'),
#  PosixPath('../../data/address/01017.csv.xz'),
#  PosixPath('../../data/address/01019.csv.xz'),
#  PosixPath('../../data/address/01021.csv.xz'),
#  PosixPath('../../data/address/01023.csv.xz'),
#  PosixPath('../../data/address/01025.csv.xz'),
#  PosixPath('../../data/address/01027.csv.xz'),
#  PosixPath('../../data/address/01029.csv.xz'),
#  PosixPath('../../data/address/01031.csv.xz'),
#  PosixPath('../../data/address/01033.csv.xz'),
#  PosixPath('../../data/address/01035.csv.xz'),
#  PosixPath('../../data/address/01037.csv.xz'),
#  PosixPath('../../data/address/01039.csv.xz'),
#  PosixPath('../../data/address/01041.csv.xz'),
#  PosixPath('../../data/address/01043.csv.xz'),
#  PosixPath('../../data/address/01045.csv.xz'),
#  PosixPath('../../data/address/01047.csv.xz'),
#  PosixPath('../../data/address/01049.csv.xz'),
#  PosixPath('../../data/address/01051.csv.xz'),
#  PosixPath('../../data/address/01053.csv.xz'),
#  PosixPath('../../data/address/01055.csv.xz'),
#  PosixPath('../../data/address/01057.csv.xz'),
#  PosixPath('../../data/address/01059.csv.xz'),
#  PosixPath('../../data/address/01061.csv.xz'),
#  PosixPath('../../data/address/01063.csv.xz'),
#  PosixPath('../../data/address/01065.csv.xz'),
#  PosixPath('../../data/address/01067.csv.xz'),
#  PosixPath('../../data/address/01069.csv.xz'),
#  PosixPath('../../data/address/01071.csv.xz'),
#  PosixPath('../../data/address/01073.csv.xz'),
#  PosixPath('../../data/address/01075.csv.xz'),
#  PosixPath('../../data/address/01077.csv.xz'),
#  PosixPath('../../data/address/01079.csv.xz'),
#  PosixPath('../../data/address/01081.csv.xz'),
#  PosixPath('../../data/address/01083.csv.xz'),
#  PosixPath('../../data/address/01085.csv.xz'),
#  PosixPath('../../data/address/01087.csv.xz'),
#  PosixPath('../../data/address/01089.csv.xz'),
#  PosixPath('../../data/address/01091.csv.xz'),
#  PosixPath('../../data/address/01093.csv.xz'),
#  PosixPath('../../data/address/01095.csv.xz'),
#  PosixPath('../../data/address/01097.csv.xz'),
#  PosixPath('../../data/address/01099.csv.xz'),
#  PosixPath('../../data/address/01101.csv.xz'),
#  PosixPath('../../data/address/01103.csv.xz'),
#  PosixPath('../../data/address/01105.csv.xz'),
#  PosixPath('../../data/address/01107.csv.xz'),
#  PosixPath('../../data/address/01109.csv.xz'),
#  PosixPath('../../data/address/01111.csv.xz'),
#  PosixPath('../../data/address/01113.csv.xz'),
#  PosixPath('../../data/address/01115.csv.xz'),
#  PosixPath('../../data/address/01117.csv.xz'),
#  PosixPath('../../data/address/01119.csv.xz'),
#  PosixPath('../../data/address/01121.csv.xz'),
#  PosixPath('../../data/address/01123.csv.xz'),
#  PosixPath('../../data/address/01125.csv.xz'),
#  PosixPath('../../data/address/01127.csv.xz'),
#  PosixPath('../../data/address/01129.csv.xz'),
#  PosixPath('../../data/address/01131.csv.xz'),
#  PosixPath('../../data/address/01133.csv.xz'),
#  PosixPath('../../data/address/02013.csv.xz'),
#  PosixPath('../../data/address/02016.csv.xz'),
#  PosixPath('../../data/address/02020.csv.xz'),
#  PosixPath('../../data/address/02050.csv.xz'),
#  PosixPath('../../data/address/02060.csv.xz'),
#  PosixPath('../../data/address/02063.csv.xz'),
#  PosixPath('../../data/address/02066.csv.xz'),
#  PosixPath('../../data/address/02068.csv.xz'),
#  PosixPath('../../data/address/02070.csv.xz'),
#  PosixPath('../../data/address/02090.csv.xz'),
#  PosixPath('../../data/address/02100.csv.xz'),
#  PosixPath('../../data/address/02105.csv.xz'),
#  PosixPath('../../data/address/02110.csv.xz'),
#  PosixPath('../../data/address/02122.csv.xz'),
#  PosixPath('../../data/address/02130.csv.xz'),
#  PosixPath('../../data/address/02150.csv.xz'),
#  PosixPath('../../data/address/02158.csv.xz'),
#  PosixPath('../../data/address/02164.csv.xz'),
#  PosixPath('../../data/address/02170.csv.xz'),
#  PosixPath('../../data/address/02180.csv.xz'),
#  PosixPath('../../data/address/02185.csv.xz'),
#  PosixPath('../../data/address/02188.csv.xz'),
#  PosixPath('../../data/address/02195.csv.xz'),
#  PosixPath('../../data/address/02198.csv.xz'),
#  PosixPath('../../data/address/02220.csv.xz'),
#  PosixPath('../../data/address/02230.csv.xz'),
#  PosixPath('../../data/address/02240.csv.xz'),
#  PosixPath('../../data/address/02275.csv.xz'),
#  PosixPath('../../data/address/02282.csv.xz'),
#  PosixPath('../../data/address/02290.csv.xz'),
#  PosixPath('../../data/address/04001.csv.xz'),
#  PosixPath('../../data/address/04003.csv.xz'),
#  PosixPath('../../data/address/04005.csv.xz'),
#  PosixPath('../../data/address/04007.csv.xz'),
#  PosixPath('../../data/address/04009.csv.xz'),
#  PosixPath('../../data/address/04011.csv.xz'),
#  PosixPath('../../data/address/04012.csv.xz'),
#  PosixPath('../../data/address/04013.csv.xz'),
#  PosixPath('../../data/address/04015.csv.xz'),
#  PosixPath('../../data/address/04017.csv.xz'),
#  PosixPath('../../data/address/04019.csv.xz'),
#  PosixPath('../../data/address/04021.csv.xz'),
#  PosixPath('../../data/address/04023.csv.xz'),
#  PosixPath('../../data/address/04025.csv.xz'),
#  PosixPath('../../data/address/04027.csv.xz'),
#  PosixPath('../../data/address/05001.csv.xz'),
#  PosixPath('../../data/address/05003.csv.xz'),
#  PosixPath('../../data/address/05005.csv.xz'),
#  PosixPath('../../data/address/05007.csv.xz'),
#  PosixPath('../../data/address/05009.csv.xz'),
#  PosixPath('../../data/address/05011.csv.xz'),
#  PosixPath('../../data/address/05013.csv.xz'),
#  PosixPath('../../data/address/05015.csv.xz'),
#  PosixPath('../../data/address/05017.csv.xz'),
#  PosixPath('../../data/address/05019.csv.xz'),
#  PosixPath('../../data/address/05021.csv.xz'),
#  PosixPath('../../data/address/05023.csv.xz'),
#  PosixPath('../../data/address/05025.csv.xz'),
#  PosixPath('../../data/address/05027.csv.xz'),
#  PosixPath('../../data/address/05029.csv.xz'),
#  PosixPath('../../data/address/05031.csv.xz'),
#  PosixPath('../../data/address/05033.csv.xz'),
#  PosixPath('../../data/address/05035.csv.xz'),
#  PosixPath('../../data/address/05037.csv.xz'),
#  PosixPath('../../data/address/05039.csv.xz'),
#  PosixPath('../../data/address/05041.csv.xz'),
#  PosixPath('../../data/address/05043.csv.xz'),
#  PosixPath('../../data/address/05045.csv.xz'),
#  PosixPath('../../data/address/05047.csv.xz'),
#  PosixPath('../../data/address/05049.csv.xz'),
#  PosixPath('../../data/address/05051.csv.xz'),
#  PosixPath('../../data/address/05053.csv.xz'),
#  PosixPath('../../data/address/05055.csv.xz'),
#  PosixPath('../../data/address/05057.csv.xz'),
#  PosixPath('../../data/address/05059.csv.xz'),
#  PosixPath('../../data/address/05061.csv.xz'),
#  PosixPath('../../data/address/05063.csv.xz'),
#  PosixPath('../../data/address/05065.csv.xz'),
#  PosixPath('../../data/address/05067.csv.xz'),
#  PosixPath('../../data/address/05069.csv.xz'),
#  PosixPath('../../data/address/05071.csv.xz'),
#  PosixPath('../../data/address/05073.csv.xz'),
#  PosixPath('../../data/address/05075.csv.xz'),
#  PosixPath('../../data/address/05077.csv.xz'),
#  PosixPath('../../data/address/05079.csv.xz'),
#  PosixPath('../../data/address/05081.csv.xz'),
#  PosixPath('../../data/address/05083.csv.xz'),
#  PosixPath('../../data/address/05085.csv.xz'),
#  PosixPath('../../data/address/05087.csv.xz'),
#  PosixPath('../../data/address/05089.csv.xz'),
#  PosixPath('../../data/address/05091.csv.xz'),
#  PosixPath('../../data/address/05093.csv.xz'),
#  PosixPath('../../data/address/05095.csv.xz'),
#  PosixPath('../../data/address/05097.csv.xz'),
#  PosixPath('../../data/address/05099.csv.xz'),
#  PosixPath('../../data/address/05101.csv.xz'),
#  PosixPath('../../data/address/05103.csv.xz'),
#  PosixPath('../../data/address/05105.csv.xz'),
#  PosixPath('../../data/address/05107.csv.xz'),
#  PosixPath('../../data/address/05109.csv.xz'),
#  PosixPath('../../data/address/05111.csv.xz'),
#  PosixPath('../../data/address/05113.csv.xz'),
#  PosixPath('../../data/address/05115.csv.xz'),
#  PosixPath('../../data/address/05117.csv.xz'),
#  PosixPath('../../data/address/05119.csv.xz'),
#  PosixPath('../../data/address/05121.csv.xz'),
#  PosixPath('../../data/address/05123.csv.xz'),
#  PosixPath('../../data/address/05125.csv.xz'),
#  PosixPath('../../data/address/05127.csv.xz'),
#  PosixPath('../../data/address/05129.csv.xz'),
#  PosixPath('../../data/address/05131.csv.xz'),
#  PosixPath('../../data/address/05133.csv.xz'),
#  PosixPath('../../data/address/05135.csv.xz'),
#  PosixPath('../../data/address/05137.csv.xz'),
#  PosixPath('../../data/address/05139.csv.xz'),
#  PosixPath('../../data/address/05141.csv.xz'),
#  PosixPath('../../data/address/05143.csv.xz'),
#  PosixPath('../../data/address/05145.csv.xz'),
#  PosixPath('../../data/address/05147.csv.xz'),
#  PosixPath('../../data/address/05149.csv.xz'),
#  PosixPath('../../data/address/06001.csv.xz'),
#  PosixPath('../../data/address/06003.csv.xz'),
#  PosixPath('../../data/address/06005.csv.xz'),
#  PosixPath('../../data/address/06007.csv.xz'),
#  PosixPath('../../data/address/06009.csv.xz'),
#  PosixPath('../../data/address/06011.csv.xz'),
#  PosixPath('../../data/address/06013.csv.xz'),
#  PosixPath('../../data/address/06015.csv.xz'),
#  PosixPath('../../data/address/06017.csv.xz'),
#  PosixPath('../../data/address/06019.csv.xz'),
#  PosixPath('../../data/address/06021.csv.xz'),
#  PosixPath('../../data/address/06023.csv.xz'),
#  PosixPath('../../data/address/06025.csv.xz'),
#  PosixPath('../../data/address/06027.csv.xz'),
#  PosixPath('../../data/address/06029.csv.xz'),
#  PosixPath('../../data/address/06031.csv.xz'),
#  PosixPath('../../data/address/06033.csv.xz'),
#  PosixPath('../../data/address/06035.csv.xz'),
#  PosixPath('../../data/address/06037.csv.xz'),
#  PosixPath('../../data/address/06039.csv.xz'),
#  PosixPath('../../data/address/06041.csv.xz'),
#  PosixPath('../../data/address/06043.csv.xz'),
#  PosixPath('../../data/address/06045.csv.xz'),
#  PosixPath('../../data/address/06047.csv.xz'),
#  PosixPath('../../data/address/06049.csv.xz'),
#  PosixPath('../../data/address/06051.csv.xz'),
#  PosixPath('../../data/address/06053.csv.xz'),
#  PosixPath('../../data/address/06055.csv.xz'),
#  PosixPath('../../data/address/06057.csv.xz'),
#  PosixPath('../../data/address/06059.csv.xz'),
#  PosixPath('../../data/address/06061.csv.xz'),
#  PosixPath('../../data/address/06063.csv.xz'),
#  PosixPath('../../data/address/06065.csv.xz'),
#  PosixPath('../../data/address/06067.csv.xz'),
#  PosixPath('../../data/address/06069.csv.xz'),
#  PosixPath('../../data/address/06071.csv.xz'),
#  PosixPath('../../data/address/06073.csv.xz'),
#  PosixPath('../../data/address/06075.csv.xz'),
#  PosixPath('../../data/address/06077.csv.xz'),
#  PosixPath('../../data/address/06079.csv.xz'),
#  PosixPath('../../data/address/06081.csv.xz'),
#  PosixPath('../../data/address/06083.csv.xz'),
#  PosixPath('../../data/address/06085.csv.xz'),
#  PosixPath('../../data/address/06087.csv.xz'),
#  PosixPath('../../data/address/06089.csv.xz'),
#  PosixPath('../../data/address/06091.csv.xz'),
#  PosixPath('../../data/address/06093.csv.xz'),
#  PosixPath('../../data/address/06095.csv.xz'),
#  PosixPath('../../data/address/06097.csv.xz'),
#  PosixPath('../../data/address/06099.csv.xz'),
#  PosixPath('../../data/address/06101.csv.xz'),
#  PosixPath('../../data/address/06103.csv.xz'),
#  PosixPath('../../data/address/06105.csv.xz'),
#  PosixPath('../../data/address/06107.csv.xz'),
#  PosixPath('../../data/address/06109.csv.xz'),
#  PosixPath('../../data/address/06111.csv.xz'),
#  PosixPath('../../data/address/06113.csv.xz'),
#  PosixPath('../../data/address/06115.csv.xz'),
#  PosixPath('../../data/address/08001.csv.xz'),
#  PosixPath('../../data/address/08003.csv.xz'),
#  PosixPath('../../data/address/08005.csv.xz'),
#  PosixPath('../../data/address/08007.csv.xz'),
#  PosixPath('../../data/address/08009.csv.xz'),
#  PosixPath('../../data/address/08011.csv.xz'),
#  PosixPath('../../data/address/08013.csv.xz'),
#  PosixPath('../../data/address/08014.csv.xz'),
#  PosixPath('../../data/address/08015.csv.xz'),
#  PosixPath('../../data/address/08017.csv.xz'),
#  PosixPath('../../data/address/08019.csv.xz'),
#  PosixPath('../../data/address/08021.csv.xz'),
#  PosixPath('../../data/address/08023.csv.xz'),
#  PosixPath('../../data/address/08025.csv.xz'),
#  PosixPath('../../data/address/08027.csv.xz'),
#  PosixPath('../../data/address/08029.csv.xz'),
#  PosixPath('../../data/address/08031.csv.xz'),
#  PosixPath('../../data/address/08033.csv.xz'),
#  PosixPath('../../data/address/08035.csv.xz'),
#  PosixPath('../../data/address/08037.csv.xz'),
#  PosixPath('../../data/address/08039.csv.xz'),
#  PosixPath('../../data/address/08041.csv.xz'),
#  PosixPath('../../data/address/08043.csv.xz'),
#  PosixPath('../../data/address/08045.csv.xz'),
#  PosixPath('../../data/address/08047.csv.xz'),
#  PosixPath('../../data/address/08049.csv.xz'),
#  PosixPath('../../data/address/08051.csv.xz'),
#  PosixPath('../../data/address/08053.csv.xz'),
#  PosixPath('../../data/address/08055.csv.xz'),
#  PosixPath('../../data/address/08057.csv.xz'),
#  PosixPath('../../data/address/08059.csv.xz'),
#  PosixPath('../../data/address/08061.csv.xz'),
#  PosixPath('../../data/address/08063.csv.xz'),
#  PosixPath('../../data/address/08065.csv.xz'),
#  PosixPath('../../data/address/08067.csv.xz'),
#  PosixPath('../../data/address/08069.csv.xz'),
#  PosixPath('../../data/address/08071.csv.xz'),
#  PosixPath('../../data/address/08073.csv.xz'),
#  PosixPath('../../data/address/08075.csv.xz'),
#  PosixPath('../../data/address/08077.csv.xz'),
#  PosixPath('../../data/address/08079.csv.xz'),
#  PosixPath('../../data/address/08081.csv.xz'),
#  PosixPath('../../data/address/08083.csv.xz'),
#  PosixPath('../../data/address/08085.csv.xz'),
#  PosixPath('../../data/address/08087.csv.xz'),
#  PosixPath('../../data/address/08089.csv.xz'),
#  PosixPath('../../data/address/08091.csv.xz'),
#  PosixPath('../../data/address/08093.csv.xz'),
#  PosixPath('../../data/address/08095.csv.xz'),
#  PosixPath('../../data/address/08097.csv.xz'),
#  PosixPath('../../data/address/08099.csv.xz'),
#  PosixPath('../../data/address/08101.csv.xz'),
#  PosixPath('../../data/address/08103.csv.xz'),
#  PosixPath('../../data/address/08105.csv.xz'),
#  PosixPath('../../data/address/08107.csv.xz'),
#  PosixPath('../../data/address/08109.csv.xz'),
#  PosixPath('../../data/address/08111.csv.xz'),
#  PosixPath('../../data/address/08113.csv.xz'),
#  PosixPath('../../data/address/08115.csv.xz'),
#  PosixPath('../../data/address/08117.csv.xz'),
#  PosixPath('../../data/address/08119.csv.xz'),
#  PosixPath('../../data/address/08121.csv.xz'),
#  PosixPath('../../data/address/08123.csv.xz'),
#  PosixPath('../../data/address/08125.csv.xz'),
#  PosixPath('../../data/address/09001.csv.xz'),
#  PosixPath('../../data/address/09003.csv.xz'),
#  PosixPath('../../data/address/09005.csv.xz'),
#  PosixPath('../../data/address/09007.csv.xz'),
#  PosixPath('../../data/address/09009.csv.xz'),
#  PosixPath('../../data/address/09011.csv.xz'),
#  PosixPath('../../data/address/09013.csv.xz'),
#  PosixPath('../../data/address/09015.csv.xz'),
#  PosixPath('../../data/address/10001.csv.xz'),
#  PosixPath('../../data/address/10003.csv.xz'),
#  PosixPath('../../data/address/10005.csv.xz'),
#  PosixPath('../../data/address/11001.csv.xz'),
#  PosixPath('../../data/address/12001.csv.xz'),
#  PosixPath('../../data/address/12003.csv.xz'),
#  PosixPath('../../data/address/12005.csv.xz'),
#  PosixPath('../../data/address/12007.csv.xz'),
#  PosixPath('../../data/address/12009.csv.xz'),
#  PosixPath('../../data/address/12011.csv.xz'),
#  PosixPath('../../data/address/12013.csv.xz'),
#  PosixPath('../../data/address/12015.csv.xz'),
#  PosixPath('../../data/address/12017.csv.xz'),
#  PosixPath('../../data/address/12019.csv.xz'),
#  PosixPath('../../data/address/12021.csv.xz'),
#  PosixPath('../../data/address/12023.csv.xz'),
#  PosixPath('../../data/address/12027.csv.xz'),
#  PosixPath('../../data/address/12029.csv.xz'),
#  PosixPath('../../data/address/12031.csv.xz'),
#  PosixPath('../../data/address/12033.csv.xz'),
#  PosixPath('../../data/address/12035.csv.xz'),
#  PosixPath('../../data/address/12037.csv.xz'),
#  PosixPath('../../data/address/12039.csv.xz'),
#  PosixPath('../../data/address/12041.csv.xz'),
#  PosixPath('../../data/address/12043.csv.xz'),
#  PosixPath('../../data/address/12045.csv.xz'),
#  PosixPath('../../data/address/12047.csv.xz'),
#  PosixPath('../../data/address/12049.csv.xz'),
#  PosixPath('../../data/address/12051.csv.xz'),
#  PosixPath('../../data/address/12053.csv.xz'),
#  PosixPath('../../data/address/12055.csv.xz'),
#  PosixPath('../../data/address/12057.csv.xz'),
#  PosixPath('../../data/address/12059.csv.xz'),
#  PosixPath('../../data/address/12061.csv.xz'),
#  PosixPath('../../data/address/12063.csv.xz'),
#  PosixPath('../../data/address/12065.csv.xz'),
#  PosixPath('../../data/address/12067.csv.xz'),
#  PosixPath('../../data/address/12069.csv.xz'),
#  PosixPath('../../data/address/12071.csv.xz'),
#  PosixPath('../../data/address/12073.csv.xz'),
#  PosixPath('../../data/address/12075.csv.xz'),
#  PosixPath('../../data/address/12077.csv.xz'),
#  PosixPath('../../data/address/12079.csv.xz'),
#  PosixPath('../../data/address/12081.csv.xz'),
#  PosixPath('../../data/address/12083.csv.xz'),
#  PosixPath('../../data/address/12085.csv.xz'),
#  PosixPath('../../data/address/12086.csv.xz'),
#  PosixPath('../../data/address/12087.csv.xz'),
#  PosixPath('../../data/address/12089.csv.xz'),
#  PosixPath('../../data/address/12091.csv.xz'),
#  PosixPath('../../data/address/12093.csv.xz'),
#  PosixPath('../../data/address/12095.csv.xz'),
#  PosixPath('../../data/address/12097.csv.xz'),
#  PosixPath('../../data/address/12099.csv.xz'),
#  PosixPath('../../data/address/12101.csv.xz'),
#  PosixPath('../../data/address/12103.csv.xz'),
#  PosixPath('../../data/address/12105.csv.xz'),
#  PosixPath('../../data/address/12107.csv.xz'),
#  PosixPath('../../data/address/12109.csv.xz'),
#  PosixPath('../../data/address/12111.csv.xz'),
#  PosixPath('../../data/address/12113.csv.xz'),
#  PosixPath('../../data/address/12115.csv.xz'),
#  PosixPath('../../data/address/12117.csv.xz'),
#  PosixPath('../../data/address/12119.csv.xz'),
#  PosixPath('../../data/address/12121.csv.xz'),
#  PosixPath('../../data/address/12123.csv.xz'),
#  PosixPath('../../data/address/12125.csv.xz'),
#  PosixPath('../../data/address/12127.csv.xz'),
#  PosixPath('../../data/address/12129.csv.xz'),
#  PosixPath('../../data/address/12131.csv.xz'),
#  PosixPath('../../data/address/12133.csv.xz'),
#  PosixPath('../../data/address/13001.csv.xz'),
#  PosixPath('../../data/address/13003.csv.xz'),
#  PosixPath('../../data/address/13005.csv.xz'),
#  PosixPath('../../data/address/13007.csv.xz'),
#  PosixPath('../../data/address/13009.csv.xz'),
#  PosixPath('../../data/address/13011.csv.xz'),
#  PosixPath('../../data/address/13013.csv.xz'),
#  PosixPath('../../data/address/13015.csv.xz'),
#  PosixPath('../../data/address/13017.csv.xz'),
#  PosixPath('../../data/address/13019.csv.xz'),
#  PosixPath('../../data/address/13021.csv.xz'),
#  PosixPath('../../data/address/13023.csv.xz'),
#  PosixPath('../../data/address/13025.csv.xz'),
#  PosixPath('../../data/address/13027.csv.xz'),
#  PosixPath('../../data/address/13029.csv.xz'),
#  PosixPath('../../data/address/13031.csv.xz'),
#  PosixPath('../../data/address/13033.csv.xz'),
#  PosixPath('../../data/address/13035.csv.xz'),
#  PosixPath('../../data/address/13037.csv.xz'),
#  PosixPath('../../data/address/13039.csv.xz'),
#  PosixPath('../../data/address/13043.csv.xz'),
#  PosixPath('../../data/address/13045.csv.xz'),
#  PosixPath('../../data/address/13047.csv.xz'),
#  PosixPath('../../data/address/13049.csv.xz'),
#  PosixPath('../../data/address/13051.csv.xz'),
#  PosixPath('../../data/address/13053.csv.xz'),
#  PosixPath('../../data/address/13055.csv.xz'),
#  PosixPath('../../data/address/13057.csv.xz'),
#  PosixPath('../../data/address/13059.csv.xz'),
#  PosixPath('../../data/address/13061.csv.xz'),
#  PosixPath('../../data/address/13063.csv.xz'),
#  PosixPath('../../data/address/13065.csv.xz'),
#  PosixPath('../../data/address/13067.csv.xz'),
#  PosixPath('../../data/address/13069.csv.xz'),
#  PosixPath('../../data/address/13071.csv.xz'),
#  PosixPath('../../data/address/13073.csv.xz'),
#  PosixPath('../../data/address/13075.csv.xz'),
#  PosixPath('../../data/address/13077.csv.xz'),
#  PosixPath('../../data/address/13079.csv.xz'),
#  PosixPath('../../data/address/13081.csv.xz'),
#  PosixPath('../../data/address/13083.csv.xz'),
#  PosixPath('../../data/address/13085.csv.xz'),
#  PosixPath('../../data/address/13087.csv.xz'),
#  PosixPath('../../data/address/13089.csv.xz'),
#  PosixPath('../../data/address/13091.csv.xz'),
#  PosixPath('../../data/address/13093.csv.xz'),
#  PosixPath('../../data/address/13095.csv.xz'),
#  PosixPath('../../data/address/13097.csv.xz'),
#  PosixPath('../../data/address/13099.csv.xz'),
#  PosixPath('../../data/address/13101.csv.xz'),
#  PosixPath('../../data/address/13103.csv.xz'),
#  PosixPath('../../data/address/13105.csv.xz'),
#  PosixPath('../../data/address/13107.csv.xz'),
#  PosixPath('../../data/address/13109.csv.xz'),
#  PosixPath('../../data/address/13111.csv.xz'),
#  PosixPath('../../data/address/13113.csv.xz'),
#  PosixPath('../../data/address/13115.csv.xz'),
#  PosixPath('../../data/address/13117.csv.xz'),
#  PosixPath('../../data/address/13119.csv.xz'),
#  PosixPath('../../data/address/13121.csv.xz'),
#  PosixPath('../../data/address/13123.csv.xz'),
#  PosixPath('../../data/address/13125.csv.xz'),
#  PosixPath('../../data/address/13127.csv.xz'),
#  PosixPath('../../data/address/13129.csv.xz'),
#  PosixPath('../../data/address/13131.csv.xz'),
#  PosixPath('../../data/address/13133.csv.xz'),
#  PosixPath('../../data/address/13135.csv.xz'),
#  PosixPath('../../data/address/13137.csv.xz'),
#  PosixPath('../../data/address/13139.csv.xz'),
#  PosixPath('../../data/address/13141.csv.xz'),
#  PosixPath('../../data/address/13143.csv.xz'),
#  PosixPath('../../data/address/13145.csv.xz'),
#  PosixPath('../../data/address/13147.csv.xz'),
#  PosixPath('../../data/address/13149.csv.xz'),
#  PosixPath('../../data/address/13151.csv.xz'),
#  PosixPath('../../data/address/13153.csv.xz'),
#  PosixPath('../../data/address/13155.csv.xz'),
#  PosixPath('../../data/address/13157.csv.xz'),
#  PosixPath('../../data/address/13159.csv.xz'),
#  PosixPath('../../data/address/13161.csv.xz'),
#  PosixPath('../../data/address/13163.csv.xz'),
#  PosixPath('../../data/address/13165.csv.xz'),
#  PosixPath('../../data/address/13167.csv.xz'),
#  PosixPath('../../data/address/13169.csv.xz'),
#  PosixPath('../../data/address/13171.csv.xz'),
#  PosixPath('../../data/address/13173.csv.xz'),
#  PosixPath('../../data/address/13175.csv.xz'),
#  PosixPath('../../data/address/13177.csv.xz'),
#  PosixPath('../../data/address/13179.csv.xz'),
#  PosixPath('../../data/address/13181.csv.xz'),
#  PosixPath('../../data/address/13183.csv.xz'),
#  PosixPath('../../data/address/13185.csv.xz'),
#  PosixPath('../../data/address/13187.csv.xz'),
#  PosixPath('../../data/address/13189.csv.xz'),
#  PosixPath('../../data/address/13191.csv.xz'),
#  PosixPath('../../data/address/13193.csv.xz'),
#  PosixPath('../../data/address/13195.csv.xz'),
#  PosixPath('../../data/address/13197.csv.xz'),
#  PosixPath('../../data/address/13199.csv.xz'),
#  PosixPath('../../data/address/13201.csv.xz'),
#  PosixPath('../../data/address/13205.csv.xz'),
#  PosixPath('../../data/address/13207.csv.xz'),
#  PosixPath('../../data/address/13209.csv.xz'),
#  PosixPath('../../data/address/13211.csv.xz'),
#  PosixPath('../../data/address/13213.csv.xz'),
#  PosixPath('../../data/address/13215.csv.xz'),
#  PosixPath('../../data/address/13217.csv.xz'),
#  PosixPath('../../data/address/13219.csv.xz'),
#  PosixPath('../../data/address/13221.csv.xz'),
#  PosixPath('../../data/address/13223.csv.xz'),
#  PosixPath('../../data/address/13225.csv.xz'),
#  PosixPath('../../data/address/13227.csv.xz'),
#  PosixPath('../../data/address/13229.csv.xz'),
#  PosixPath('../../data/address/13231.csv.xz'),
#  PosixPath('../../data/address/13233.csv.xz'),
#  PosixPath('../../data/address/13235.csv.xz'),
#  PosixPath('../../data/address/13237.csv.xz'),
#  PosixPath('../../data/address/13239.csv.xz'),
#  PosixPath('../../data/address/13241.csv.xz'),
#  PosixPath('../../data/address/13243.csv.xz'),
#  PosixPath('../../data/address/13245.csv.xz'),
#  PosixPath('../../data/address/13247.csv.xz'),
#  PosixPath('../../data/address/13249.csv.xz'),
#  PosixPath('../../data/address/13251.csv.xz'),
#  PosixPath('../../data/address/13253.csv.xz'),
#  PosixPath('../../data/address/13255.csv.xz'),
#  PosixPath('../../data/address/13257.csv.xz'),
#  PosixPath('../../data/address/13259.csv.xz'),
#  PosixPath('../../data/address/13261.csv.xz'),
#  PosixPath('../../data/address/13263.csv.xz'),
#  PosixPath('../../data/address/13265.csv.xz'),
#  PosixPath('../../data/address/13267.csv.xz'),
#  PosixPath('../../data/address/13269.csv.xz'),
#  PosixPath('../../data/address/13271.csv.xz'),
#  PosixPath('../../data/address/13273.csv.xz'),
#  PosixPath('../../data/address/13275.csv.xz'),
#  PosixPath('../../data/address/13277.csv.xz'),
#  PosixPath('../../data/address/13279.csv.xz'),
#  PosixPath('../../data/address/13281.csv.xz'),
#  PosixPath('../../data/address/13283.csv.xz'),
#  PosixPath('../../data/address/13285.csv.xz'),
#  PosixPath('../../data/address/13287.csv.xz'),
#  PosixPath('../../data/address/13289.csv.xz'),
#  PosixPath('../../data/address/13291.csv.xz'),
#  PosixPath('../../data/address/13293.csv.xz'),
#  PosixPath('../../data/address/13295.csv.xz'),
#  PosixPath('../../data/address/13297.csv.xz'),
#  PosixPath('../../data/address/13299.csv.xz'),
#  PosixPath('../../data/address/13301.csv.xz'),
#  PosixPath('../../data/address/13303.csv.xz'),
#  PosixPath('../../data/address/13305.csv.xz'),
#  PosixPath('../../data/address/13307.csv.xz'),
#  PosixPath('../../data/address/13309.csv.xz'),
#  PosixPath('../../data/address/13311.csv.xz'),
#  PosixPath('../../data/address/13313.csv.xz'),
#  PosixPath('../../data/address/13315.csv.xz'),
#  PosixPath('../../data/address/13317.csv.xz'),
#  PosixPath('../../data/address/13319.csv.xz'),
#  PosixPath('../../data/address/13321.csv.xz'),
#  PosixPath('../../data/address/15001.csv.xz'),
#  PosixPath('../../data/address/15003.csv.xz'),
#  PosixPath('../../data/address/15005.csv.xz'),
#  PosixPath('../../data/address/15007.csv.xz'),
#  PosixPath('../../data/address/15009.csv.xz'),
#  PosixPath('../../data/address/16001.csv.xz'),
#  PosixPath('../../data/address/16003.csv.xz'),
#  PosixPath('../../data/address/16005.csv.xz'),
#  PosixPath('../../data/address/16007.csv.xz'),
#  PosixPath('../../data/address/16009.csv.xz'),
#  PosixPath('../../data/address/16011.csv.xz'),
#  PosixPath('../../data/address/16013.csv.xz'),
#  PosixPath('../../data/address/16015.csv.xz'),
#  PosixPath('../../data/address/16017.csv.xz'),
#  PosixPath('../../data/address/16019.csv.xz'),
#  PosixPath('../../data/address/16021.csv.xz'),
#  PosixPath('../../data/address/16023.csv.xz'),
#  PosixPath('../../data/address/16025.csv.xz'),
#  PosixPath('../../data/address/16027.csv.xz'),
#  PosixPath('../../data/address/16029.csv.xz'),
#  PosixPath('../../data/address/16031.csv.xz'),
#  PosixPath('../../data/address/16033.csv.xz'),
#  PosixPath('../../data/address/16035.csv.xz'),
#  PosixPath('../../data/address/16037.csv.xz'),
#  PosixPath('../../data/address/16039.csv.xz'),
#  PosixPath('../../data/address/16041.csv.xz'),
#  PosixPath('../../data/address/16043.csv.xz'),
#  PosixPath('../../data/address/16045.csv.xz'),
#  PosixPath('../../data/address/16047.csv.xz'),
#  PosixPath('../../data/address/16049.csv.xz'),
#  PosixPath('../../data/address/16051.csv.xz'),
#  PosixPath('../../data/address/16053.csv.xz'),
#  PosixPath('../../data/address/16055.csv.xz'),
#  PosixPath('../../data/address/16057.csv.xz'),
#  PosixPath('../../data/address/16059.csv.xz'),
#  PosixPath('../../data/address/16061.csv.xz'),
#  PosixPath('../../data/address/16063.csv.xz'),
#  PosixPath('../../data/address/16065.csv.xz'),
#  PosixPath('../../data/address/16067.csv.xz'),
#  PosixPath('../../data/address/16069.csv.xz'),
#  PosixPath('../../data/address/16071.csv.xz'),
#  PosixPath('../../data/address/16073.csv.xz'),
#  PosixPath('../../data/address/16075.csv.xz'),
#  PosixPath('../../data/address/16077.csv.xz'),
#  PosixPath('../../data/address/16079.csv.xz'),
#  PosixPath('../../data/address/16081.csv.xz'),
#  PosixPath('../../data/address/16083.csv.xz'),
#  PosixPath('../../data/address/16085.csv.xz'),
#  PosixPath('../../data/address/16087.csv.xz'),
#  PosixPath('../../data/address/17001.csv.xz'),
#  PosixPath('../../data/address/17003.csv.xz'),
#  PosixPath('../../data/address/17005.csv.xz'),
#  PosixPath('../../data/address/17007.csv.xz'),
#  PosixPath('../../data/address/17009.csv.xz'),
#  PosixPath('../../data/address/17011.csv.xz'),
#  PosixPath('../../data/address/17013.csv.xz'),
#  PosixPath('../../data/address/17015.csv.xz'),
#  PosixPath('../../data/address/17017.csv.xz'),
#  PosixPath('../../data/address/17019.csv.xz'),
#  PosixPath('../../data/address/17021.csv.xz'),
#  PosixPath('../../data/address/17023.csv.xz'),
#  PosixPath('../../data/address/17025.csv.xz'),
#  PosixPath('../../data/address/17027.csv.xz'),
#  PosixPath('../../data/address/17029.csv.xz'),
#  PosixPath('../../data/address/17031.csv.xz'),
#  PosixPath('../../data/address/17033.csv.xz'),
#  PosixPath('../../data/address/17035.csv.xz'),
#  PosixPath('../../data/address/17037.csv.xz'),
#  PosixPath('../../data/address/17039.csv.xz'),
#  PosixPath('../../data/address/17041.csv.xz'),
#  PosixPath('../../data/address/17043.csv.xz'),
#  PosixPath('../../data/address/17045.csv.xz'),
#  PosixPath('../../data/address/17047.csv.xz'),
#  PosixPath('../../data/address/17049.csv.xz'),
#  PosixPath('../../data/address/17051.csv.xz'),
#  PosixPath('../../data/address/17053.csv.xz'),
#  PosixPath('../../data/address/17055.csv.xz'),
#  PosixPath('../../data/address/17057.csv.xz'),
#  PosixPath('../../data/address/17059.csv.xz'),
#  PosixPath('../../data/address/17061.csv.xz'),
#  PosixPath('../../data/address/17063.csv.xz'),
#  PosixPath('../../data/address/17065.csv.xz'),
#  PosixPath('../../data/address/17067.csv.xz'),
#  PosixPath('../../data/address/17069.csv.xz'),
#  PosixPath('../../data/address/17071.csv.xz'),
#  PosixPath('../../data/address/17073.csv.xz'),
#  PosixPath('../../data/address/17075.csv.xz'),
#  PosixPath('../../data/address/17077.csv.xz'),
#  PosixPath('../../data/address/17079.csv.xz'),
#  PosixPath('../../data/address/17081.csv.xz'),
#  PosixPath('../../data/address/17083.csv.xz'),
#  PosixPath('../../data/address/17085.csv.xz'),
#  PosixPath('../../data/address/17087.csv.xz'),
#  PosixPath('../../data/address/17089.csv.xz'),
#  PosixPath('../../data/address/17091.csv.xz'),
#  PosixPath('../../data/address/17093.csv.xz'),
#  PosixPath('../../data/address/17095.csv.xz'),
#  PosixPath('../../data/address/17097.csv.xz'),
#  PosixPath('../../data/address/17099.csv.xz'),
#  PosixPath('../../data/address/17101.csv.xz'),
#  PosixPath('../../data/address/17103.csv.xz'),
#  PosixPath('../../data/address/17105.csv.xz'),
#  PosixPath('../../data/address/17107.csv.xz'),
#  PosixPath('../../data/address/17109.csv.xz'),
#  PosixPath('../../data/address/17111.csv.xz'),
#  PosixPath('../../data/address/17113.csv.xz'),
#  PosixPath('../../data/address/17115.csv.xz'),
#  PosixPath('../../data/address/17117.csv.xz'),
#  PosixPath('../../data/address/17119.csv.xz'),
#  PosixPath('../../data/address/17121.csv.xz'),
#  PosixPath('../../data/address/17123.csv.xz'),
#  PosixPath('../../data/address/17125.csv.xz'),
#  PosixPath('../../data/address/17127.csv.xz'),
#  PosixPath('../../data/address/17129.csv.xz'),
#  PosixPath('../../data/address/17131.csv.xz'),
#  PosixPath('../../data/address/17133.csv.xz'),
#  PosixPath('../../data/address/17135.csv.xz'),
#  PosixPath('../../data/address/17137.csv.xz'),
#  PosixPath('../../data/address/17139.csv.xz'),
#  PosixPath('../../data/address/17141.csv.xz'),
#  PosixPath('../../data/address/17143.csv.xz'),
#  PosixPath('../../data/address/17145.csv.xz'),
#  PosixPath('../../data/address/17147.csv.xz'),
#  PosixPath('../../data/address/17149.csv.xz'),
#  PosixPath('../../data/address/17151.csv.xz'),
#  PosixPath('../../data/address/17153.csv.xz'),
#  PosixPath('../../data/address/17155.csv.xz'),
#  PosixPath('../../data/address/17157.csv.xz'),
#  PosixPath('../../data/address/17159.csv.xz'),
#  PosixPath('../../data/address/17161.csv.xz'),
#  PosixPath('../../data/address/17163.csv.xz'),
#  PosixPath('../../data/address/17165.csv.xz'),
#  PosixPath('../../data/address/17167.csv.xz'),
#  PosixPath('../../data/address/17169.csv.xz'),
#  PosixPath('../../data/address/17171.csv.xz'),
#  PosixPath('../../data/address/17173.csv.xz'),
#  PosixPath('../../data/address/17175.csv.xz'),
#  PosixPath('../../data/address/17177.csv.xz'),
#  PosixPath('../../data/address/17179.csv.xz'),
#  PosixPath('../../data/address/17181.csv.xz'),
#  PosixPath('../../data/address/17183.csv.xz'),
#  PosixPath('../../data/address/17185.csv.xz'),
#  PosixPath('../../data/address/17187.csv.xz'),
#  PosixPath('../../data/address/17189.csv.xz'),
#  PosixPath('../../data/address/17191.csv.xz'),
#  PosixPath('../../data/address/17193.csv.xz'),
#  PosixPath('../../data/address/17195.csv.xz'),
#  PosixPath('../../data/address/17197.csv.xz'),
#  PosixPath('../../data/address/17199.csv.xz'),
#  PosixPath('../../data/address/17201.csv.xz'),
#  PosixPath('../../data/address/17203.csv.xz'),
#  PosixPath('../../data/address/18001.csv.xz'),
#  PosixPath('../../data/address/18003.csv.xz'),
#  PosixPath('../../data/address/18005.csv.xz'),
#  PosixPath('../../data/address/18007.csv.xz'),
#  PosixPath('../../data/address/18009.csv.xz'),
#  PosixPath('../../data/address/18011.csv.xz'),
#  PosixPath('../../data/address/18013.csv.xz'),
#  PosixPath('../../data/address/18015.csv.xz'),
#  PosixPath('../../data/address/18017.csv.xz'),
#  PosixPath('../../data/address/18019.csv.xz'),
#  PosixPath('../../data/address/18021.csv.xz'),
#  PosixPath('../../data/address/18023.csv.xz'),
#  PosixPath('../../data/address/18025.csv.xz'),
#  PosixPath('../../data/address/18027.csv.xz'),
#  PosixPath('../../data/address/18029.csv.xz'),
#  PosixPath('../../data/address/18031.csv.xz'),
#  PosixPath('../../data/address/18033.csv.xz'),
#  PosixPath('../../data/address/18035.csv.xz'),
#  PosixPath('../../data/address/18037.csv.xz'),
#  PosixPath('../../data/address/18039.csv.xz'),
#  PosixPath('../../data/address/18041.csv.xz'),
#  PosixPath('../../data/address/18043.csv.xz'),
#  PosixPath('../../data/address/18045.csv.xz'),
#  PosixPath('../../data/address/18047.csv.xz'),
#  PosixPath('../../data/address/18049.csv.xz'),
#  PosixPath('../../data/address/18051.csv.xz'),
#  PosixPath('../../data/address/18053.csv.xz'),
#  PosixPath('../../data/address/18055.csv.xz'),
#  PosixPath('../../data/address/18057.csv.xz'),
#  PosixPath('../../data/address/18059.csv.xz'),
#  PosixPath('../../data/address/18061.csv.xz'),
#  PosixPath('../../data/address/18063.csv.xz'),
#  PosixPath('../../data/address/18065.csv.xz'),
#  PosixPath('../../data/address/18067.csv.xz'),
#  PosixPath('../../data/address/18069.csv.xz'),
#  PosixPath('../../data/address/18071.csv.xz'),
#  PosixPath('../../data/address/18073.csv.xz'),
#  PosixPath('../../data/address/18075.csv.xz'),
#  PosixPath('../../data/address/18077.csv.xz'),
#  PosixPath('../../data/address/18079.csv.xz'),
#  PosixPath('../../data/address/18081.csv.xz'),
#  PosixPath('../../data/address/18083.csv.xz'),
#  PosixPath('../../data/address/18085.csv.xz'),
#  PosixPath('../../data/address/18087.csv.xz'),
#  PosixPath('../../data/address/18089.csv.xz'),
#  PosixPath('../../data/address/18091.csv.xz'),
#  PosixPath('../../data/address/18093.csv.xz'),
#  PosixPath('../../data/address/18095.csv.xz'),
#  PosixPath('../../data/address/18097.csv.xz'),
#  PosixPath('../../data/address/18099.csv.xz'),
#  PosixPath('../../data/address/18101.csv.xz'),
#  PosixPath('../../data/address/18103.csv.xz'),
#  PosixPath('../../data/address/18105.csv.xz'),
#  PosixPath('../../data/address/18107.csv.xz'),
#  PosixPath('../../data/address/18109.csv.xz'),
#  PosixPath('../../data/address/18111.csv.xz'),
#  PosixPath('../../data/address/18113.csv.xz'),
#  PosixPath('../../data/address/18115.csv.xz'),
#  PosixPath('../../data/address/18117.csv.xz'),
#  PosixPath('../../data/address/18119.csv.xz'),
#  PosixPath('../../data/address/18121.csv.xz'),
#  PosixPath('../../data/address/18123.csv.xz'),
#  PosixPath('../../data/address/18125.csv.xz'),
#  PosixPath('../../data/address/18127.csv.xz'),
#  PosixPath('../../data/address/18129.csv.xz'),
#  PosixPath('../../data/address/18131.csv.xz'),
#  PosixPath('../../data/address/18133.csv.xz'),
#  PosixPath('../../data/address/18135.csv.xz'),
#  PosixPath('../../data/address/18137.csv.xz'),
#  PosixPath('../../data/address/18139.csv.xz'),
#  PosixPath('../../data/address/18141.csv.xz'),
#  PosixPath('../../data/address/18143.csv.xz'),
#  PosixPath('../../data/address/18145.csv.xz'),
#  PosixPath('../../data/address/18147.csv.xz'),
#  PosixPath('../../data/address/18149.csv.xz'),
#  PosixPath('../../data/address/18151.csv.xz'),
#  PosixPath('../../data/address/18153.csv.xz'),
#  PosixPath('../../data/address/18155.csv.xz'),
#  PosixPath('../../data/address/18157.csv.xz'),
#  PosixPath('../../data/address/18159.csv.xz'),
#  PosixPath('../../data/address/18161.csv.xz'),
#  PosixPath('../../data/address/18163.csv.xz'),
#  PosixPath('../../data/address/18165.csv.xz'),
#  PosixPath('../../data/address/18167.csv.xz'),
#  PosixPath('../../data/address/18169.csv.xz'),
#  PosixPath('../../data/address/18171.csv.xz'),
#  PosixPath('../../data/address/18173.csv.xz'),
#  PosixPath('../../data/address/18175.csv.xz'),
#  PosixPath('../../data/address/18177.csv.xz'),
#  PosixPath('../../data/address/18179.csv.xz'),
#  PosixPath('../../data/address/18181.csv.xz'),
#  PosixPath('../../data/address/18183.csv.xz'),
#  PosixPath('../../data/address/19001.csv.xz'),
#  PosixPath('../../data/address/19003.csv.xz'),
#  PosixPath('../../data/address/19005.csv.xz'),
#  PosixPath('../../data/address/19007.csv.xz'),
#  PosixPath('../../data/address/19009.csv.xz'),
#  PosixPath('../../data/address/19011.csv.xz'),
#  PosixPath('../../data/address/19013.csv.xz'),
#  PosixPath('../../data/address/19015.csv.xz'),
#  PosixPath('../../data/address/19017.csv.xz'),
#  PosixPath('../../data/address/19019.csv.xz'),
#  PosixPath('../../data/address/19021.csv.xz'),
#  PosixPath('../../data/address/19023.csv.xz'),
#  PosixPath('../../data/address/19025.csv.xz'),
#  PosixPath('../../data/address/19027.csv.xz'),
#  PosixPath('../../data/address/19029.csv.xz'),
#  PosixPath('../../data/address/19031.csv.xz'),
#  PosixPath('../../data/address/19033.csv.xz'),
#  PosixPath('../../data/address/19035.csv.xz'),
#  PosixPath('../../data/address/19037.csv.xz'),
#  PosixPath('../../data/address/19039.csv.xz'),
#  PosixPath('../../data/address/19041.csv.xz'),
#  PosixPath('../../data/address/19043.csv.xz'),
#  PosixPath('../../data/address/19045.csv.xz'),
#  PosixPath('../../data/address/19047.csv.xz'),
#  PosixPath('../../data/address/19049.csv.xz'),
#  PosixPath('../../data/address/19051.csv.xz'),
#  PosixPath('../../data/address/19053.csv.xz'),
#  PosixPath('../../data/address/19055.csv.xz'),
#  PosixPath('../../data/address/19057.csv.xz'),
#  PosixPath('../../data/address/19059.csv.xz'),
#  PosixPath('../../data/address/19061.csv.xz'),
#  PosixPath('../../data/address/19063.csv.xz'),
#  PosixPath('../../data/address/19065.csv.xz'),
#  PosixPath('../../data/address/19067.csv.xz'),
#  PosixPath('../../data/address/19069.csv.xz'),
#  PosixPath('../../data/address/19071.csv.xz'),
#  PosixPath('../../data/address/19073.csv.xz'),
#  PosixPath('../../data/address/19075.csv.xz'),
#  PosixPath('../../data/address/19077.csv.xz'),
#  PosixPath('../../data/address/19079.csv.xz'),
#  PosixPath('../../data/address/19081.csv.xz'),
#  PosixPath('../../data/address/19083.csv.xz'),
#  PosixPath('../../data/address/19085.csv.xz'),
#  PosixPath('../../data/address/19087.csv.xz'),
#  PosixPath('../../data/address/19089.csv.xz'),
#  PosixPath('../../data/address/19091.csv.xz'),
#  PosixPath('../../data/address/19093.csv.xz'),
#  PosixPath('../../data/address/19095.csv.xz'),
#  PosixPath('../../data/address/19097.csv.xz'),
#  PosixPath('../../data/address/19099.csv.xz'),
#  PosixPath('../../data/address/19101.csv.xz'),
#  PosixPath('../../data/address/19103.csv.xz'),
#  PosixPath('../../data/address/19105.csv.xz'),
#  PosixPath('../../data/address/19107.csv.xz'),
#  PosixPath('../../data/address/19109.csv.xz'),
#  PosixPath('../../data/address/19111.csv.xz'),
#  PosixPath('../../data/address/19113.csv.xz'),
#  PosixPath('../../data/address/19115.csv.xz'),
#  PosixPath('../../data/address/19117.csv.xz'),
#  PosixPath('../../data/address/19119.csv.xz'),
#  PosixPath('../../data/address/19121.csv.xz'),
#  PosixPath('../../data/address/19123.csv.xz'),
#  PosixPath('../../data/address/19125.csv.xz'),
#  PosixPath('../../data/address/19127.csv.xz'),
#  PosixPath('../../data/address/19129.csv.xz'),
#  PosixPath('../../data/address/19131.csv.xz'),
#  PosixPath('../../data/address/19133.csv.xz'),
#  PosixPath('../../data/address/19135.csv.xz'),
#  PosixPath('../../data/address/19137.csv.xz'),
#  PosixPath('../../data/address/19139.csv.xz'),
#  PosixPath('../../data/address/19141.csv.xz'),
#  PosixPath('../../data/address/19143.csv.xz'),
#  PosixPath('../../data/address/19145.csv.xz'),
#  PosixPath('../../data/address/19147.csv.xz'),
#  PosixPath('../../data/address/19149.csv.xz'),
#  PosixPath('../../data/address/19151.csv.xz'),
#  PosixPath('../../data/address/19153.csv.xz'),
#  PosixPath('../../data/address/19155.csv.xz'),
#  PosixPath('../../data/address/19157.csv.xz'),
#  PosixPath('../../data/address/19159.csv.xz'),
#  PosixPath('../../data/address/19161.csv.xz'),
#  PosixPath('../../data/address/19163.csv.xz'),
#  PosixPath('../../data/address/19165.csv.xz'),
#  PosixPath('../../data/address/19167.csv.xz'),
#  PosixPath('../../data/address/19169.csv.xz'),
#  PosixPath('../../data/address/19171.csv.xz'),
#  PosixPath('../../data/address/19173.csv.xz'),
#  PosixPath('../../data/address/19175.csv.xz'),
#  PosixPath('../../data/address/19177.csv.xz'),
#  PosixPath('../../data/address/19179.csv.xz'),
#  PosixPath('../../data/address/19181.csv.xz'),
#  PosixPath('../../data/address/19183.csv.xz'),
#  PosixPath('../../data/address/19185.csv.xz'),
#  PosixPath('../../data/address/19187.csv.xz'),
#  PosixPath('../../data/address/19189.csv.xz'),
#  PosixPath('../../data/address/19191.csv.xz'),
#  PosixPath('../../data/address/19193.csv.xz'),
#  PosixPath('../../data/address/19195.csv.xz'),
#  PosixPath('../../data/address/19197.csv.xz'),
#  PosixPath('../../data/address/20001.csv.xz'),
#  PosixPath('../../data/address/20003.csv.xz'),
#  PosixPath('../../data/address/20005.csv.xz'),
#  PosixPath('../../data/address/20007.csv.xz'),
#  PosixPath('../../data/address/20009.csv.xz'),
#  PosixPath('../../data/address/20011.csv.xz'),
#  PosixPath('../../data/address/20013.csv.xz'),
#  PosixPath('../../data/address/20015.csv.xz'),
#  PosixPath('../../data/address/20017.csv.xz'),
#  PosixPath('../../data/address/20019.csv.xz'),
#  PosixPath('../../data/address/20021.csv.xz'),
#  PosixPath('../../data/address/20023.csv.xz'),
#  PosixPath('../../data/address/20025.csv.xz'),
#  PosixPath('../../data/address/20027.csv.xz'),
#  PosixPath('../../data/address/20029.csv.xz'),
#  PosixPath('../../data/address/20031.csv.xz'),
#  PosixPath('../../data/address/20033.csv.xz'),
#  PosixPath('../../data/address/20035.csv.xz'),
#  PosixPath('../../data/address/20037.csv.xz'),
#  PosixPath('../../data/address/20039.csv.xz'),
#  PosixPath('../../data/address/20041.csv.xz'),
#  PosixPath('../../data/address/20043.csv.xz'),
#  PosixPath('../../data/address/20045.csv.xz'),
#  PosixPath('../../data/address/20047.csv.xz'),
#  PosixPath('../../data/address/20049.csv.xz'),
#  PosixPath('../../data/address/20051.csv.xz'),
#  PosixPath('../../data/address/20053.csv.xz'),
#  PosixPath('../../data/address/20055.csv.xz'),
#  PosixPath('../../data/address/20057.csv.xz'),
#  PosixPath('../../data/address/20059.csv.xz'),
#  PosixPath('../../data/address/20061.csv.xz'),
#  PosixPath('../../data/address/20063.csv.xz'),
#  PosixPath('../../data/address/20065.csv.xz'),
#  PosixPath('../../data/address/20067.csv.xz'),
#  PosixPath('../../data/address/20069.csv.xz'),
#  PosixPath('../../data/address/20071.csv.xz'),
#  PosixPath('../../data/address/20073.csv.xz'),
#  PosixPath('../../data/address/20075.csv.xz'),
#  PosixPath('../../data/address/20077.csv.xz'),
#  PosixPath('../../data/address/20079.csv.xz'),
#  PosixPath('../../data/address/20081.csv.xz'),
#  PosixPath('../../data/address/20083.csv.xz'),
#  PosixPath('../../data/address/20085.csv.xz'),
#  PosixPath('../../data/address/20087.csv.xz'),
#  PosixPath('../../data/address/20089.csv.xz'),
#  PosixPath('../../data/address/20091.csv.xz'),
#  PosixPath('../../data/address/20093.csv.xz'),
#  PosixPath('../../data/address/20095.csv.xz'),
#  PosixPath('../../data/address/20097.csv.xz'),
#  PosixPath('../../data/address/20099.csv.xz'),
#  PosixPath('../../data/address/20101.csv.xz'),
#  PosixPath('../../data/address/20103.csv.xz'),
#  PosixPath('../../data/address/20105.csv.xz'),
#  PosixPath('../../data/address/20107.csv.xz'),
#  PosixPath('../../data/address/20109.csv.xz'),
#  PosixPath('../../data/address/20111.csv.xz'),
#  PosixPath('../../data/address/20113.csv.xz'),
#  PosixPath('../../data/address/20115.csv.xz'),
#  PosixPath('../../data/address/20117.csv.xz'),
#  PosixPath('../../data/address/20119.csv.xz'),
#  PosixPath('../../data/address/20121.csv.xz'),
#  PosixPath('../../data/address/20123.csv.xz'),
#  PosixPath('../../data/address/20125.csv.xz'),
#  PosixPath('../../data/address/20127.csv.xz'),
#  PosixPath('../../data/address/20129.csv.xz'),
#  PosixPath('../../data/address/20131.csv.xz'),
#  PosixPath('../../data/address/20133.csv.xz'),
#  PosixPath('../../data/address/20135.csv.xz'),
#  PosixPath('../../data/address/20137.csv.xz'),
#  PosixPath('../../data/address/20139.csv.xz'),
#  PosixPath('../../data/address/20141.csv.xz'),
#  PosixPath('../../data/address/20143.csv.xz'),
#  PosixPath('../../data/address/20145.csv.xz'),
#  PosixPath('../../data/address/20147.csv.xz'),
#  PosixPath('../../data/address/20149.csv.xz'),
#  PosixPath('../../data/address/20151.csv.xz'),
#  PosixPath('../../data/address/20153.csv.xz'),
#  PosixPath('../../data/address/20155.csv.xz'),
#  PosixPath('../../data/address/20157.csv.xz'),
#  PosixPath('../../data/address/20159.csv.xz'),
#  PosixPath('../../data/address/20161.csv.xz'),
#  PosixPath('../../data/address/20163.csv.xz'),
#  PosixPath('../../data/address/20165.csv.xz'),
#  PosixPath('../../data/address/20167.csv.xz'),
#  PosixPath('../../data/address/20169.csv.xz'),
#  PosixPath('../../data/address/20171.csv.xz'),
#  PosixPath('../../data/address/20173.csv.xz'),
#  PosixPath('../../data/address/20175.csv.xz'),
#  PosixPath('../../data/address/20177.csv.xz'),
#  PosixPath('../../data/address/20179.csv.xz'),
#  PosixPath('../../data/address/20181.csv.xz'),
#  PosixPath('../../data/address/20183.csv.xz'),
#  PosixPath('../../data/address/20185.csv.xz'),
#  PosixPath('../../data/address/20187.csv.xz'),
#  PosixPath('../../data/address/20189.csv.xz'),
#  PosixPath('../../data/address/20191.csv.xz'),
#  PosixPath('../../data/address/20193.csv.xz'),
#  PosixPath('../../data/address/20195.csv.xz'),
#  PosixPath('../../data/address/20197.csv.xz'),
#  PosixPath('../../data/address/20199.csv.xz'),
#  PosixPath('../../data/address/20201.csv.xz'),
#  PosixPath('../../data/address/20203.csv.xz'),
#  PosixPath('../../data/address/20205.csv.xz'),
#  PosixPath('../../data/address/20207.csv.xz'),
#  PosixPath('../../data/address/20209.csv.xz'),
#  PosixPath('../../data/address/21001.csv.xz'),
#  PosixPath('../../data/address/21003.csv.xz'),
#  PosixPath('../../data/address/21005.csv.xz'),
#  PosixPath('../../data/address/21007.csv.xz'),
#  PosixPath('../../data/address/21009.csv.xz'),
#  PosixPath('../../data/address/21011.csv.xz'),
#  ...]

# %%
pbar = tqdm(xz_files)
error_files = {}
for file in pbar:
    try:
        county_fip = file.name.split('.')[0]
        pbar.set_description('(%s) Checking county: %s, %s' % (len(error_files), file, county_fip))
        adf = pd.read_csv(file, dtype={'GEOID20':object})
        sdf = gpd.read_file(os.path.join(shapefile_dir,'%s.geojson' % county_fip))
        
        errors = []
            
    except Exception as e:
        errors.append('Exception occured: %s' % e)
    finally:
        if not set(sdf['GEOID20']) == set(adf['GEOID20']):
            errors.append('GEOID column mismatch')
            
        if county_fip != sdf['GEOID20'].values[0][:5]:
            errors.append('County prefix mismatch')
        
        if len(errors) > 0:
            error_files[county_fip] = errors
print('Mismatch in files: %s' % len(error_files))
# Out:
# (0) Checking county: ../../data/address/72113.csv.xz, 72113:  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████▎| 3200/3221 [58:01<00:02,  9.08it/s]

# %%
error_files
# Out:
# {'01001': [],
#  '01003': [],
#  '01005': [],
#  '01007': [],
#  '01009': [],
#  '01011': [],
#  '01013': [],
#  '01015': [],
#  '01017': [],
#  '01019': [],
#  '01021': [],
#  '01023': [],
#  '01025': [],
#  '01027': [],
#  '01029': [],
#  '01031': [],
#  '01033': [],
#  '01035': []}

# %% [markdown]
# # For every error, fix it!!

# %%
def get_geojson(fip, save_dir ='../../data/shapefiles/'):
    prefix = 'https://www2.census.gov/geo/tiger/TIGER2020PL/LAYER/TABBLOCK/2020/'
    r= requests.get(prefix)
    soup = BeautifulSoup(r.content)
    shape_zips = []
    for a in soup.find_all('a', href=True):
        if not '.zip' in a['href'] or len(a['href'])!= 28: # filter for the entire state ones
            continue
        shape_zips.append(a['href'])
    to_download = [v for v in shape_zips if fip in v][0]
    gdf = gpd.read_file(prefix+to_download)
    save_filepath = os.path.join(save_dir, '%s.geojson' % fip)
    gdf.to_file(save_filepath)
    assert os.path.isfile(save_filepath)

# %%
get_geojson('06037')

# %%
error_files
# Out:
# ['09001', '39097']

# %%
def download_missing_geojsons(fips, shapefile_dir='../../data/shapefiles/'):
    for fip in fips:
        if os.path.isfile(os.path.join(shapefile_dir, '%s.geojson' % fip)):
            continue # skip if file already exists
        print('Downloading: %s' % fip)
        get_geojson(fip)

# %%
download_missing_geojsons(error_files)
# Out:
# Downloading: 39097

# %%
def generate_empty_xz_file(fip, address_dir = '../../data/address/'):
    print('Generating .xz for: %s' % fip)
    assert os.path.isfile(os.path.join(shapefile_dir, '%s.geojson' % fip)), print('No geojson for: %s' % fip)
    sdf = gpd.read_file(os.path.join(shapefile_dir,'%s.geojson' % fip))
    cols = ['address','GEOID20', 'longitude', 'latitude']
    adf = sdf.reindex(columns=cols)
    # print(adf)
    adf.to_csv(os.path.join(address_dir, '%s.csv.xz' % fip), index=False)
    assert os.path.isfile(os.path.join(address_dir, '%s.csv.xz' % fip))

# %%
for e in error_files:
    generate_empty_xz_file(e)
# Out:
# Generating .xz for: 09001
# Generating .xz for: 39097

# %%
# def fix_xz_file(fip, address_dir = '../../data/address/', shapefile_dir='../../data/shapefiles/'):
#     assert os.path.isfile(os.path.join(address_dir, '%s.csv.xz' % fip)), print('No csv.xz for: %s' % fip)
#     assert os.path.isfile(os.path.join(shapefile_dir, '%s.geojson' % fip)), print('No geojson for: %s' % fip)
#     adf = pd.read_csv(os.path.join(address_dir, '%s.csv.xz'%fip), dtype={'GEOID20':object})
#     sdf = gpd.read_file(os.path.join(shapefile_dir,'%s.geojson' % fip))
#     # print(fip)
#     print(os.path.join(shapefile_dir, '%s.geojson' % fip))
#     # print(set(sdf['GEOID20']).symmetric_difference(set(adf['GEOID20'])))
#     print('[%s]: %s: %s' % (fip, len(sdf['GEOID20'].unique()), len(adf['GEOID20'].unique())))

# for e in error_files:
#     fix_xz_file(e)
# Out:
# ../../data/shapefiles/09001.geojson
# [09001]: 10997: 10997
# ../../data/shapefiles/39097.geojson
# [39097]: 1373: 1373
